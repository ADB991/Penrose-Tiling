# %%
import numpy as np

# %%
0.5*(1+np.sqrt(5))
# Out:
# 1.618033988749895

# %%
import tiles

# %%
tiles.PHI
# Out:
# 1.618033988749895

# %%
np.pi
# Out:
# 3.141592653589793

# %%
np.cos(3)
# Out:
# -0.9899924966004454

# %%
tiles.CENTRE_PHI_ROTATION
# Out:
# matrix([[ 0.80901699,  0.58778525],
#         [-0.58778525,  0.80901699]])

# %%
np.zeros((5,2))[0:2]
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
vertices = np.zeros((5,2))
vertices[0:2] = np.array([(1,2),(2,3)])
vertices
# Out:
# array([[1., 2.],
#        [2., 3.],
#        [0., 0.],
#        [0., 0.],
#        [0., 0.]])

# %%
for i in range(2,6):
    print(i)
# Out:
# 2
# 3
# 4
# 5

# %%
np.array([1,0])*(tiles.rotation_matrix(tiles.PHI_ANGLE).T)
# Out:
# matrix([[0.30901699, 0.95105652]])

# %%
p = tiles.Pentagon((0,0),(1,0))

# %%
p.vertices
# Out:
# array([[ 0.        ,  0.        ],
#        [ 1.        ,  0.        ],
#        [ 1.30901699,  0.95105652],
#        [ 0.5       ,  1.53884177],
#        [-0.30901699,  0.95105652]])

# %%
import matplotlib.pyplot as plt

# %%
x = p.vertices[:,0]
y = p.vertices[:,1]

# %%
list(p.loop_vertices())
# Out:
# [array([0., 0.]),
#  array([1., 0.]),
#  array([1.30901699, 0.95105652]),
#  array([0.5       , 1.53884177]),
#  array([-0.30901699,  0.95105652]),
#  array([0., 0.])]

# %%
for v in p.loop_vertices():
    print(v)
# Out:
# [0. 0.]
# [1. 0.]
# [1.30901699 0.95105652]
# [0.5        1.53884177]
# [-0.30901699  0.95105652]
# [0. 0.]

# %%
for penta in p.deflate():
    print(penta.vertices)
# Out:
# [[ 0.          0.        ]
#  [ 0.38196601  0.        ]
#  [ 0.5         0.36327126]
#  [ 0.19098301  0.58778525]
#  [-0.11803399  0.36327126]]
# [[1.         0.        ]
#  [1.11803399 0.36327126]
#  [0.80901699 0.58778525]
#  [0.5        0.36327126]
#  [0.61803399 0.        ]]
# [[1.30901699 0.95105652]
#  [1.         1.1755705 ]
#  [0.69098301 0.95105652]
#  [0.80901699 0.58778525]
#  [1.19098301 0.58778525]]
# [[0.5        1.53884177]
#  [0.19098301 1.31432778]
#  [0.30901699 0.95105652]
#  [0.69098301 0.95105652]
#  [0.80901699 1.31432778]]
# [[-3.09016994e-01  9.51056516e-01]
#  [-1.90983006e-01  5.87785252e-01]
#  [ 1.90983006e-01  5.87785252e-01]
#  [ 3.09016994e-01  9.51056516e-01]
#  [ 3.88578059e-16  1.17557050e+00]]
# [[0.5        0.36327126]
#  [0.80901699 0.58778525]
#  [0.69098301 0.95105652]
#  [0.30901699 0.95105652]
#  [0.19098301 0.58778525]]

# %%
(np.zeros(2)+np.ones(2)*tiles.PHI_ROTATION)[0]
# Out:
# matrix([[-0.64203952,  1.26007351]])

# %%
def plot_pentagon(penta):
    coords = penta.loop_vertices_as_array()
    x, y = coords[:,0], coords[:,1]
    plt.plot(x,y,'g')

# %%
def plot_pentagons(pentagon_generator):
    for penta in list(pentagon_generator)[:]:
        plot_pentagon(penta)
    plt.show()

# %%
plot_pentagons(p.deflate())

# %%
tiles.PHI_SCALE
# Out:
# 0.38196601125010515

# %%
np.array(list(p.loop_vertices()))
# Out:
# array([[ 0.        ,  0.        ],
#        [ 1.        ,  0.        ],
#        [ 1.30901699,  0.95105652],
#        [ 0.5       ,  1.53884177],
#        [-0.30901699,  0.95105652],
#        [ 0.        ,  0.        ]])

# %%
p.loop_vertices_as_array()
# Out:
# array([[ 0.        ,  0.        ],
#        [ 1.        ,  0.        ],
#        [ 1.30901699,  0.95105652],
#        [ 0.5       ,  1.53884177],
#        [-0.30901699,  0.95105652],
#        [ 0.        ,  0.        ]])

# %%
x = []
x += [1,2,3]
x
# Out:
# [1, 2, 3]

# %%
t = tiles.Tiling([p])
t.deflate()
plot_pentagons(t.tiles)

# %%
len(t.tiles)
# Out:
# 46656

# %%
import time
t = tiles.Tiling([p])
ts = [time.time()]
tile_list = [t.tiles]
for i in range(10):
    t.deflate()
    print(time.time()-ts[-1])
    tile_list += [t.tiles]
    ts += [time.time()]
# Out:
# 0.002232074737548828
# 0.0052182674407958984
# 0.020680904388427734
# 0.1072697639465332
# 0.599524974822998
# 3.5415351390838623
# 21.41312289237976
# 126.65757894515991
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-1fc50fd55fbc> in <module>()
#       4 tile_list = [t.tiles]
#       5 for i in range(10):
# ----> 6     t.deflate()
#       7     print(time.time()-ts[-1])
#       8     tile_list += [t.tiles]
#
# ~/Documents/Penrose Tiling/processing/pentagons/tiles.py in deflate(self, iterations)
#      79             new_tiles = []
#      80             for tile in self.tiles:
# ---> 81                 new_tiles += list(tile.deflate())
#      82             self.tiles = new_tiles
#      83
#
# ~/Documents/Penrose Tiling/processing/pentagons/tiles.py in deflate(self)
#      60             displacement = v1 - v0
#      61             new_vertex = PHI_SCALE * displacement + v0
# ---> 62             yield Pentagon(v0, new_vertex)
#      63         # the pentagon at the centre
#      64         v0, v1 = self.vertices[:2] #grab the two vertices
#
# ~/Documents/Penrose Tiling/processing/pentagons/tiles.py in __init__(self, coords1, coords2)
#      34         vertices[:2] = np.array([coords1,coords2])
#      35         for i in range(2,5):
# ---> 36             displacement = vertices[i-1] - vertices[i-2]
#      37             displacement = displacement*PHI_ROTATION
#      38             vertices[i] = vertices[i-1]+displacement
#
# KeyboardInterrupt:

# %%
time.time()
# Out:
# 1533227469.14331

# %%
plot_pentagons(tile_list[4])
